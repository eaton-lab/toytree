# %% [markdown]
# ## IPCOAL WITH ANCIENT SAMPLES

# %%
import ipcoal
import toytree
import msprime as ms

# %% [markdown]
# ## Species tree

# %%
tre = toytree.rtree.rtree(5, treeheight=1e6, seed=33333)
tre.draw(ts='p', edge_type='p');
# Out:
# <div class="toyplot" id="t116ef3d292a444c0b7bf95ccb4bd54be" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="260.0px" id="t2eb72782bdb84f95ade1d69c4f775979" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 350.0 260.0" width="350.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="te5d56193988e41fdaea7e1bc24aa97c3"><clipPath id="t9c948e5ada9e40ac8ee83becaee7243b"><rect height="200.0" width="290.0" x="30.0" y="30.0"></rect></clipPath><g clip-path="url(#t9c948e5ada9e40ac8ee83becaee7243b)"><g class="toyplot-mark-Graph" id="t12932dfb9f3d4f059f86d5128984e8cc"><g class="toyplot-Edges"><path d="M 293.73
# ...

# %%
self = ipcoal.Model(tre, Ne=1e4, nsamples=2)
self.sim_loci(1, 15000)
self.infer_gene_trees()
self.df.head()
# Out:
# wrote concat locus (10 x 15000bp) to /tmp/9143.phy
#    locus  start    end  nbps  nsnps  tidx                    genealogy  \
# 0      0      0   2151  2151     38     0  ((r0-0:8129,r0-1:8129):3...
# 1      0   2151   8420  6269    117     1  ((r0-0:8129,r0-1:8129):3...
# 2      0   8420   8519    99      2     2  ((r0-0:8129,r0-1:8129):2...
# 3      0   8519  15000  6481    128     3  ((r0-0:8129,r0-1:8129):2...
#
#                  inferred_tree
# 0  (r0-1:0.0000666703231137...
# 1  (r0-1:0.0000666703231137...
# 2  (r0-1:0.0000666703231137...
# 3  (r0-1:0.0000666703231137...

# %% [markdown]
# ## Genealogy

# %%
gtre = toytree.tree(self.df.genealogy[0]).root(regex="r0")
gtre.draw(ts='c', tip_labels=True, edge_type='p');
# Out:
# <div class="toyplot" id="t04a1a1ab4b684e28b9965cf9a449b15d" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="270.0px" id="t0c2a13ab85ac4e90ab645b1cae720c5b" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 350.0 270.0" width="350.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t099c182ba14f4097a80bf10d6c95d1b3"><clipPath id="t412c085bce784511ba7f87d1b3295627"><rect height="210.0" width="290.0" x="30.0" y="30.0"></rect></clipPath><g clip-path="url(#t412c085bce784511ba7f87d1b3295627)"><g class="toyplot-mark-Graph" id="ta484bf58ac8d4a7994df8e4822deb3f6"><g class="toyplot-Edges"><path d="M 280.53
# ...

# %% [markdown]
# ## Inferred

# %%
itre = toytree.tree(self.df.inferred_tree[0]).root(regex="r0")
itre.draw(ts='c', tip_labels=True, edge_type='p');
# Out:
# <div class="toyplot" id="t7dd1a87557674c14a2d1ae8a653966c3" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="270.0px" id="t6645d48a24d94b29a6b4d88209de59aa" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 350.0 270.0" width="350.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t1fa14eb0de754e829bc78e8955c75f8a"><clipPath id="te633fd666f45456592bb7b5b7345a50c"><rect height="210.0" width="290.0" x="30.0" y="30.0"></rect></clipPath><g clip-path="url(#te633fd666f45456592bb7b5b7345a50c)"><g class="toyplot-mark-Graph" id="tb4ef677157774b38b495722ac4978eb0"><g class="toyplot-Edges"><path d="M 280.53
# ...

# %% [markdown]
# ### PROBLEMS WITH ADMIXTURE

# %%
tre = toytree.rtree.rtree(5, treeheight=1e6, seed=33333)
tre.draw(ts='p', edge_type='p');
# Out:
# <div class="toyplot" id="t957c1192a56e463aab5c752de0de2798" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="260.0px" id="t9db7d38895bc43a482d725fa519ee542" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 350.0 260.0" width="350.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t79a461174c9844af83818ad642bee6ae"><clipPath id="t4c9fd96044c042bebe6a3e4235190d8c"><rect height="200.0" width="290.0" x="30.0" y="30.0"></rect></clipPath><g clip-path="url(#t4c9fd96044c042bebe6a3e4235190d8c)"><g class="toyplot-mark-Graph" id="tbbb7952f6f5041c0aed678d06a435e0e"><g class="toyplot-Edges"><path d="M 293.73
# ...

# %%
self = ipcoal.Model(tre, Ne=1e4, admixture_edges=[(0, 2, 0.5, 0.5)])
self.sim_trees(1, 15000)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-b8217f841066> in <module>
# ----> 1 self = ipcoal.Model(tre, Ne=1e4, admixture_edges=[(0, 2, 0.5, 0.5)])
#       2 self.sim_trees(1, 15000)
#
# ~/Documents/ipcoal/ipcoal/Model.py in __init__(self, tree, Ne, admixture_edges, admixture_type, nsamples, mut, recomb, recomb_map, seed, seed_mutations, substitution_model, debug, **kwargs)
#     237
#     238         # get migration time, rate {mrates: [], mtimes: []}
# --> 239         self._get_migration()
#     240
#     241         # get .ms_demography dict for msprime input
#
# ~/Documents/ipcoal/ipcoal/Model.py in _get_migration(self)
#     509             dnode = self.tree.treenode.search_nodes(idx=iedge[1])[0]
#     510             ival = intervals.get((snode.idx, dnode.idx))
# --> 511             dist_ival = ival[1] - ival[0]
#     512
# ...
