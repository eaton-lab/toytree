# %% [markdown]
# # Draw networks
#
# This page demonstrates how to draw parsed network information as a tree plus admixture edges.

# %% [markdown]
# ### Basic workflow
#
# 1. Parse an extended Newick network string or file into a major tree and admixture mapping.
# 2. Draw the major tree with `tree.draw(...)`.
# 3. Add admixture edges using annotation helpers.

# %%
import toytree

# Example placeholder; replace with a real network string/path
# tree, admixture = toytree.network.parse_network(network_text)
# c, a, m = tree.draw()
# ... add admixture edges ...
# c
